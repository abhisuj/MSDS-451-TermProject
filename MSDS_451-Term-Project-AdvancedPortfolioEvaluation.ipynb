# %%
# Import refactored module
import sys
sys.path.append('.')
from portfolio_config_refactored import generate_all_portfolios

# Generate all three portfolios
weights_df, metrics_df, results = generate_all_portfolios(
    mu=mu,
    avg_annual_yield=avg_annual_yield,
    predicted_simple_returns_filtered=predicted_simple_returns_filtered,
    predicted_cov_matrices_time_series=predicted_cov_matrices_time_series,
    test_dates=test_dates,
    asset_tickers=asset_tickers,
    actual_test_returns=actual_test_returns,
    population_size=POPULATION_SIZE,
    n_generations=N_GENERATIONS
)

# Display results
display(metrics_df)
display(weights_df)

for strategy in weights_df.columns:
    print(f"\n📊 {strategy}:")
    active_weights = weights_df[strategy][weights_df[strategy] > 0.01].sort_values(ascending=False)
    print(f"   Active positions: {len(active_weights)}")
    print(f"   Largest holdings:")
    for ticker, weight in active_weights.head(5).items():
        print(f"      {ticker:8s}: {weight:7.2%}")

print("\n✅ Complete! Check files:")
print("   📄 selected_portfolio_weights.csv")
print("   📄 selected_portfolio_metrics.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 8
#       4 from portfolio_config_refactored import generate_all_portfolios
#       6 # Generate all three portfolios
#       7 weights_df, metrics_df, results = generate_all_portfolios(
# ----> 8     mu=mu,
#       9     avg_annual_yield=avg_annual_yield,
#      10     predicted_simple_returns_filtered=predicted_simple_returns_filtered,
#      11     predicted_cov_matrices_time_series=predicted_cov_matrices_time_series,
#      12     test_dates=test_dates,
#      13     asset_tickers=asset_tickers,
#      14     actual_test_returns=actual_test_returns,
#      15     population_size=POPULATION_SIZE,
#      16     n_generations=N_GENERATIONS
#      17 )
#      19 # Display results
#      20 display(metrics_df)
#
# NameError: name 'mu' is not defined
